# %%
import pandas as pd
import numpy as np
import os

BASE = "/content/ecopackai"
DATA_PATH = f"/content/materials_engineered.csv"
OUTPUT_PATH = f"{BASE}/data/model_input"

os.makedirs(OUTPUT_PATH, exist_ok=True)

# %%
df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (404, 31)
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# 1      Void-fill and cushioning for fragile products            APAC
# 2  Secure, high-load international shipping and l...        AMERICAS
# 3      Void-fill and cushioning for fragile products             ROW
# 4      Void-fill and cushioning for fragile products           LATAM
#
#    Recyclability (%) Recyclability Category  Recycled Content (%)  \
# 0                 98                   High                  79.0
# 1                100                   High                  93.0
# 2                 87                   High                  78.0
# 3                100                   High                  89.0
# 4                100                   High                  92.0
#
#    Reusability (%)  ...  Total Material Weight (tons)  \
# 0             49.0  ...                         790.0
# 1             31.0  ...                         545.0
# 2            100.0  ...                        4979.0
# 3             31.0  ...                         656.0
# 4             28.0  ...                         549.0
#
#    Supplier Sustainability Compliance (%)  Weight per Unit (g)  \
# 0                                    85.0          7801.698598
# 1                                    88.0          7368.748394
# 2                                    88.0        339886.681685
# 3                                    81.0          8742.470281
# 4                                    81.0          7932.494329
#
#    Cost per kg (USD)  CO2_Impact_Index_raw  CO2_Impact_Index  \
# 0           0.287117              0.215183             21.52
# 1           0.246989              0.147690             14.77
# 2           0.073554              0.870000             87.00
# 3           0.277953              0.146007             14.60
# 4           0.213048              0.164028             16.40
#
#    Cost_Efficiency_Index_raw  Cost_Efficiency_Index  \
# 0                   0.704681                  70.47
# 1                   0.714471                  71.45
# 2                   0.174145                  17.41
# 3                   0.700252                  70.03
# 4                   0.717501                  71.75
#
#    Material_Suitability_Score_raw  Material_Suitability_Score
# 0                        0.440278                       44.03
# 1                        0.253472                       25.35
# 2                        0.774306                       77.43
# 3                        0.162500                       16.25
# 4                        0.225694                       22.57
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Material ID                             404 non-null    object
#  1   Packaging Type                          404 non-null    object
#  2   Material Type                           404 non-null    object
#  3   Suitable Product Categories             404 non-null    object
#  4   Recommended Packaging Use Cases         404 non-null    object
#  5   Supplier Region                         404 non-null    object
#  6   Recyclability (%)                       404 non-null    int64
#  7   Recyclability Category                  404 non-null    object
#  8   Recycled Content (%)                    403 non-null    float64
#  9   Reusability (%)                         403 non-null    float64
#  10  Biodegradation Time (days)              403 non-null    float64
#  11  End-of-Life Disposal (%)                403 non-null    float64
#  12  Carbon Footprint (kg CO2/unit)          403 non-null    float64
#  13  CO2 Emission per kg (estimated)         403 non-null    float64
#  14  Waste Reduction Impact (%)              403 non-null    float64
#  15  Sustainability Target Progress (%)      403 non-null    float64
#  16  Load Handling Score                     403 non-null    float64
#  17  Moisture Resistance Score               403 non-null    float64
#  18  Thermal Resistance Score                403 non-null    float64
#  19  Cost per Unit (USD)                     403 non-null    float64
#  20  Annual Usage (units)                    403 non-null    float64
#  21  Total Material Weight (tons)            403 non-null    float64
#  22  Supplier Sustainability Compliance (%)  403 non-null    float64
#  23  Weight per Unit (g)                     403 non-null    float64
#  24  Cost per kg (USD)                       403 non-null    float64
#  25  CO2_Impact_Index_raw                    404 non-null    float64
#  26  CO2_Impact_Index                        404 non-null    float64
#  27  Cost_Efficiency_Index_raw               403 non-null    float64
#  28  Cost_Efficiency_Index                   404 non-null    float64
#  29  Material_Suitability_Score_raw          404 non-null    float64
#  30  Material_Suitability_Score              404 non-null    float64
# dtypes: float64(23), int64(1), object(7)
# memory usage: 98.0+ KB

# %%
df.isna().sum()
# Out:
# Material ID                               0
# Packaging Type                            0
# Material Type                             0
# Suitable Product Categories               0
# Recommended Packaging Use Cases           0
# Supplier Region                           0
# Recyclability (%)                         0
# Recyclability Category                    0
# Recycled Content (%)                      1
# Reusability (%)                           1
# Biodegradation Time (days)                1
# End-of-Life Disposal (%)                  1
# Carbon Footprint (kg CO2/unit)            1
# CO2 Emission per kg (estimated)           1
# Waste Reduction Impact (%)                1
# Sustainability Target Progress (%)        1
# Load Handling Score                       1
# Moisture Resistance Score                 1
# Thermal Resistance Score                  1
# Cost per Unit (USD)                       1
# Annual Usage (units)                      1
# Total Material Weight (tons)              1
# Supplier Sustainability Compliance (%)    1
# Weight per Unit (g)                       1
# Cost per kg (USD)                         1
# CO2_Impact_Index_raw                      0
# CO2_Impact_Index                          0
# Cost_Efficiency_Index_raw                 1
# Cost_Efficiency_Index                     0
# Material_Suitability_Score_raw            0
# Material_Suitability_Score                0
# dtype: int64

# %%
# If column already exists, rename for consistency
if "Material Type" in df.columns:
    df["recommended_material"] = df["Material Type"]
else:
    raise Exception("Material Type column missing")

# %%
df["sustainability_score"] = 100 - df["CO2_Impact_Index"]

# %%
def cost_bucket(x):
    if x < 33:
        return "Low-cost"
    elif x < 66:
        return "Medium-cost"
    else:
        return "High-cost"

df["cost_efficiency_category"] = df["Cost_Efficiency_Index"].apply(cost_bucket)

# %%
target_cols = [
    "recommended_material",
    "sustainability_score",
    "cost_efficiency_category"
]

df[target_cols].head()
# Out:
#   recommended_material  sustainability_score cost_efficiency_category
# 0            Cardboard                 78.48                High-cost
# 1      Paper/Bio-Based                 85.23                High-cost
# 2                Steel                 13.00                 Low-cost
# 3      Paper/Bio-Based                 85.40                High-cost
# 4      Paper/Bio-Based                 83.60                High-cost

# %%
material_features = [
    "Material Type",
    "Density",
    "Strength Score",
    "Moisture_resistance",
    "Thermal_resistance",
    "Load_handling",
    "CO2_per_kg",
    "Biodegradation Time (days)",
    "Recyclability Category",
    "Renewable_Content_Percentage"
]

product_features = [
    "Product Category",
    "Fragility Score",
    "Weight Category",
    "Moisture Sensitivity",
    "Temperature Sensitivity",
    "Transportation Distance",
    "Expected Shelf Life (days)"
]

cost_features = [
    "Cost_per_kg",
    "Manufacturing Cost",
    "Supply Chain Availability",
    "Regional Restrictions"
]

# %%
feature_cols = material_features + product_features + cost_features

# Keep only existing columns
feature_cols = [c for c in feature_cols if c in df.columns]

print("Final Feature Count:", len(feature_cols))
feature_cols
# Out:
# Final Feature Count: 3
# ['Material Type', 'Biodegradation Time (days)', 'Recyclability Category']

# %%
drop_cols = [
    "MaterialID",
    "Material Description",
    "CO2_Impact_Index",
    "Cost_Efficiency_Index",
    "Material_Suitability_Score"
]

df_model = df.drop(columns=[c for c in drop_cols if c in df.columns])

# %%
X = df_model[feature_cols]
y = df_model[target_cols]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)

X.head()
# Out:
# X shape: (404, 3)
# y shape: (404, 3)
#      Material Type  Biodegradation Time (days) Recyclability Category
# 0        Cardboard                       188.0                   High
# 1  Paper/Bio-Based                        65.0                   High
# 2            Steel                    180208.0                   High
# 3  Paper/Bio-Based                        65.0                   High
# 4  Paper/Bio-Based                       122.0                   High

# %%
X.to_csv(f"{OUTPUT_PATH}/X_raw.csv", index=False)

# %%
y.to_csv(f"{OUTPUT_PATH}/y_raw.csv", index=False)

# %%
import os

doc = """
## Features & Targets — Dataset Preparation (Week 4)

### Target Variables
- recommended_material (classification)
- sustainability_score (regression, 0–100)
- cost_efficiency_category (Low / Medium / High)

### Feature Groups
Material Properties:
- {}

Product Requirements:
- {}

Cost & Operations:
- {}
""".format(
    ", ".join(material_features),
    ", ".join(product_features),
    ", ".join(cost_features)
)

# Ensure the directory exists before writing the file
os.makedirs(f"{BASE}/docs", exist_ok=True)

with open(f"{BASE}/docs/data_dictionary_features_targets.md", "w") as f:
    f.write(doc)
